# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

target_dir = '/content/gdrive/My Drive/colab-materials-data8-notebooks/materials-sp22-colab/'
# !test -d "$target_dir" || (mkdir -p "$(dirname "$target_dir")" && git clone https://github.com/data-8/materials-sp22-colab "$target_dir")

# %pip install -q otter-grader
# Initialize Otter
import otter
grader = otter.Notebook(colab=True)

# %% [markdown]
# ## Assignment: Fitting an Exponential Model

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 7)
y = np.array([2.00, 2.70, 3.65, 4.95, 6.70, 9.05, 12.20])

# %% [markdown]
# ## Learning goals
# * Treat a function as a map from input data x to output data y
# * Fit a simple exponential model to data and interpret parameter
# * Practice basic plotting and working with vectors
#
# ## Fit an exponential model to data
#
# You are given data vectors x and y. Assume the data follows an exponential model:
#
# $$
# y \approx a \exp(bx) = a \mathrm{e}^{bx}
# $$
#
#
# 1. Estimate the parameters $a$ and $b$ using the idea that:
#
# $$
# \ln(y) \approx \ln(a) + bx
# $$
#
# 2. Create predicted values $yhat = a*exp(b*x)$
#
#
# 3. Make a plot showing the original and predicted data

# %% [markdown]
# **Question 1**: Use the `polyfit` function from `numpy` (`np`) to find the values of `a` and `b` using the data points `x` and transformed $log(y)$ (`np.log(y)`)? store the output into an object called `p`.

# %%
p = ...

# %%
grader.check("q1")

# %% [markdown]
# **Question 2**: Using the results from `p`, create 2 new objects called `a`, `b`.

# %%
b = ...
a = ...

# %%
grader.check("q2")

# %% [markdown]
# **Question 3**: Create predicted values $yhat = a*exp(b*x)$, label the object called `yhat`.

# %%
yhat = ...

# %%
grader.check("q3")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 4:**
#
# Make a plot, using `matplotlib` showing:
#
# 1. The original data (x,y) as points
# 2. The fitted curve (x, yhat) as a smooth curve or line through points

# %%
fig, ax = plt.subplots()

...

plt.show()

# %%
grader.check("q4")

# %% [markdown]
# <!-- END QUESTION -->

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(pdf=False, run_tests=True)
