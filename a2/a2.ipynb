# %%
# Initialize Otter
# %pip install otter-grader==6.1.6

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # download test files
    import requests, os
    os.makedirs('tests', exist_ok=True)
    api = "https://api.github.com/repos/inqs909/d260_hw/contents/a2/tests"
    for f in requests.get(api).json():
        open(f"tests/{f['name']}", 'w').write(requests.get(f['download_url']).text)

    # Initialize Otter
    import otter
    grader = otter.Notebook()
else:
    import otter
    grader = otter.Notebook("a2.ipynb")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Assignment: Simulating a Linear Model

# %% [markdown]
# ### Learning Goals
#
# ### Assignment
#
# A function can be viewed as a **data map**: it takes an input vector and produces an output vector. In this problem you will generate artificial data from a linear model:
#
# $$
# f(x) = mx+b
# $$
#
# ### Tasks
# 1. Create an input vector `x` containing values from 0 to 10 (inclusive) in steps of 1.
# 2. Use $m = 2.5$ and $b = -1$ to compute model outputs.
# 3. Add small random noise so the data looks realistic. Use:
#     1. `np.random.seed(909)` to make results reproducible
#     2. `np.random.randn(*x.shape)` to add noise
# 4. Make a plot of the synthetic data as points.

# %% [markdown]
# **Question 1:** Create an input vector `x` containing values from 0 to 10 (inclusive) in steps of 1.

# %%
x = ...

# %%
grader.check("q1")

# %% [markdown]
# **Question 2:** Use $m = 2.5$ and $c = -1$ to compute model outputs. Place the output in an object called `y_mod`.

# %%
m = 2.5
c = -1
y_mod = m * x + c # SOLUUTION

# %%
grader.check("q2")

# %% [markdown]
# **Question 3:** Add error to `ym` using the code `np.random.randn(*x.shape)` into a new object called `y_obs`. The `np.random.seed(909)` sets a seed for reproducibility.

# %%
np.random.seed(909)
y_obs = ...

# %%
y_obs

# %%
grader.check("q3")

# %% [markdown]
# **Question 4:**
#
# Make a scatter plot, using `matplotlib` showing. Set the object as `ax`.

# %%
fig, ax = plt.subplots()

...

plt.show()

# %%
grader.check("q4")

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will check if submitted code is ready to be graded. **Please save before submitting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.check_all()
