# %%
# Initialize Otter
# %pip install otter-grader==6.1.6

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # download test files
    import requests, os
    os.makedirs('tests', exist_ok=True)
    api = "https://api.github.com/repos/inqs909/d260_hw/contents/a3/tests"
    for f in requests.get(api).json():
        open(f"tests/{f['name']}", 'w').write(requests.get(f['download_url']).text)

    # Initialize Otter
    import otter
    grader = otter.Notebook()
else:
    import otter
    grader = otter.Notebook("a3.ipynb")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Training loss over epochs (do not change)
t = np.arange(1, 9).reshape(-1, 1)
y = np.array([0.92, 0.78, 0.66, 0.58, 0.53, 0.50, 0.485, 0.477]).reshape(-1, 1)

# Target time (do not change)
t0 = 5

# %% [markdown]
# ## Assignment: Forward Average Rate of Change (Limits Intuition)
#
# In data science, we often track how a quantity changes over time (training loss, error, engagement, etc.). The average rate of change from time $t$ to $t+h$ is:
#
# $$
# \frac{f(t+h)-f(t)}{h}
# $$
#
# To estimate the “rate right now,” we compute average rates over smaller and smaller time steps $h$. You are given a time series $(t,y)$ representing training loss over epochs.
#
# ### Tasks
#
# 1. Compute the forward average rate of change from each point to the next (change in output vs. change in input):
#
# $$
# r_i = \frac{y_{i+1}-y_i}{t_{i+1}-t_i}
# $$
#
# 2. Find the forward rate near a target epoch `t0`:
#
# 3. Plot `y` vs `t` and mark the point at `t0` (a marker is enough).

# %% [markdown]
# **Question 1:** Create an object called `rate_forward` that computes the forward average rates between consecutive points.

# %%
rate_forward = ...

# %%
grader.check("q1")

# %% [markdown]
# **Question 2:** Find the value of $k_0$ such that $t=$ `t0`. Set the value equal to `k0`.

# %%
k0 = ...

# %%
grader.check("q2")

# %% [markdown]
# **Question 3:** Find the rate at `t0` from the object `rate_forward`. Set the value in an object called `rate_at_t0`.

# %%
rate_at_t0 = ...

# %%
grader.check("q3")

# %% [markdown]
# **Question 4:** Create a plot of `y` vs `t` and mark the point at `t0` (a marker is enough). Place the plot in an object called `ax`.

# %%
fig, ax = plt.subplots()

...

plt.show()

# %%
grader.check("q4")

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will check if submitted code is ready to be graded. **Please save before submitting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.check_all()
