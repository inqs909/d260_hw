# %%
# Initialize Otter
# %pip install otter-grader==6.1.6

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # download test files
    import requests, os
    os.makedirs('tests', exist_ok=True)
    api = "https://api.github.com/repos/inqs909/d260_hw/contents/a4/tests"
    for f in requests.get(api).json():
        open(f"tests/{f['name']}", 'w').write(requests.get(f['download_url']).text)

    # Initialize Otter
    import otter
    grader = otter.Notebook()
else:
    import otter
    grader = otter.Notebook("a4.ipynb")

# %%
import numpy as np
import matplotlib.pyplot as plt

t0 = 2

# Shrinking intervals
h = np.array([1, 0.5, 0.1, 0.01, 0.001])

# %% [markdown]
# ## Assignment X: Instantaneous Rate of Change

# %% [markdown]
# ### Learning Goals
#
#
# ### Instantaneous Rate
#
# In data science, we often want to understand how quickly something is changing at a particular moment. For example, analysts studying social media engagement might model how the number of shares of a post changes over time. Suppose the number of shares of a post after t hours is modeled by
#
# $$
# S(t) = t^2
# $$
#
# where  is time in hours.
#
# In this problem, you will approximate the instantaneous rate of change of a function by computing average rates of change over smaller and smaller time intervals. We will not use the function `np.diff`.
# We will use the forward difference:
#
# $$
# \frac{S(t_0+h)-S(t_0)}{h}
# $$
#
# As $h\rightarrow 0$, these average rates approach the derivative $S^\prime(t_0)$.
#
# You will:
# 1. Compute forward average rates for several step sizes $h$
# 2. Visualize how the rates change as $h$ shrinks
# 3. Estimate the derivative at $t_0$

# %% [markdown]
# **Question 1:** Create a user-defined function called `S` that will follows the function $S(t)=t^2$

# %%
def S(t):
    ...

# %%
grader.check("q1")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 2:** The object `t0` and `h` contains the starting point and change, respectively. Print out the objects `t0` and `h`.

# %%
...
...

# %% [markdown]
# <!-- END QUESTION -->
#
# **Question 3:** Create an object called `rate` that computes the forward difference: $\frac{S(t_0+h)-S(t_0)}{h}$.

# %%
rate = ...

# %%
grader.check("q3")

# %% [markdown]
# **Question 4:** Obtain the derivative estimates from the `rate` object, place the value in an object called `deriv_est`. (Hint: last element).

# %%
deriv_est = ...

# %%
grader.check("q4")

# %% [markdown]
# **Question 5:** Create a plot, called `ax`, visualizing the rate of changes with the different step sizes.

# %%
fig, ax = plt.subplots()

...

plt.show()

# %%
grader.check("q5")

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will check if submitted code is ready to be graded. **Please save before submitting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.check_all()
