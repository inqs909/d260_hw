# %%
# Initialize Otter
# %pip install otter-grader==6.1.6

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # download test files
    import requests, os
    os.makedirs('tests', exist_ok=True)
    api = "https://api.github.com/repos/inqs909/d260_hw/contents/a5/tests"
    for f in requests.get(api).json():
        open(f"tests/{f['name']}", 'w').write(requests.get(f['download_url']).text)

    # Initialize Otter
    import otter
    grader = otter.Notebook()
else:
    import otter
    grader = otter.Notebook("a5.ipynb")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data points (do not change)
x = np.array([1, 2, 3])
y = np.array([2, 3, 5])

# Grid of parameter values (do not change)
m_vals = np.linspace(0, 2, 41)
b_vals = np.linspace(0, 2, 41)

# %% [markdown]
# ## Assignment: Fitting Line with Least Squares

# %% [markdown]
# ### Learning Goals
#
# This activity is meant to help you build intuition for ordinary least squares (OLS) and optimization in more than one variable.
#
# ### Assignment
#
# In this activity, you will work with the data points
#
# $$
# (1,2)\ \ (2,3)\ \ (3,5)
# $$
#
# and the linear model
#
# $$
# \hat y = mx+b
# $$
#
# For each choice of slope  and intercept , we can compute the total squared error:
#
# $$
# L(m,b) = \sum^3_{i=1} (y_i-(mx_i+b))^2
# $$
#
#
# ### Your goals are to:
# - Compute the loss on a grid of $(m,b)$ values,
# - Find the grid point with the smallest loss,
# - Identify the corresponding values of $m$ and $b$,
# - Plot the data together with the best-fit line.

# %% [markdown]
# **Question 1:**

# %%
Loss = np.zeros((len(m_vals), len(b_vals)))

for i in range(len(m_vals)):
    for j in range(len(b_vals)):
        ...

# %%
grader.check("q1")

# %% [markdown]
# **Question 2:**

# %%
idx = ...
minLoss = ...

# %%
grader.check("q2")

# %% [markdown]
# **Question 3:**

# %%
i_min, j_min = np.unravel_index(idx, Loss.shape) 
m_best = ...
b_best = ...

# %%
print(m_best)
print(b_best)

# %%
grader.check("q3")

# %% [markdown]
# **Question 4:**

# %%
yhat = ...

# %%
yhat

# %%
grader.check("q4")

# %% [markdown]
# **Question 5:**

# %%
fig, ax = plt.subplots()
...
plt.show()

# %%
grader.check("q5")

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will check if submitted code is ready to be graded. **Please save before submitting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.check_all()
