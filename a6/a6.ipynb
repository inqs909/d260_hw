# %%
# Initialize Otter
# %pip install otter-grader==6.1.6

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # download test files
    import requests, os
    os.makedirs('tests', exist_ok=True)
    api = "https://api.github.com/repos/inqs909/d260_hw/contents/a6/tests"
    for f in requests.get(api).json():
        open(f"tests/{f['name']}", 'w').write(requests.get(f['download_url']).text)

    # Initialize Otter
    import otter
    grader = otter.Notebook()
else:
    import otter
    grader = otter.Notebook("a6.ipynb")

# %% [markdown]
# ## Assignment X: Critical Points and Concavity of an Engagement Model

# %%
import numpy as np
import matplotlib.pyplot as plt

# Time interval (do not change)
t = np.linspace(0, 6, 400)

# %% [markdown]
# A social media platform tracks the engagement score of a post over time. Suppose the score is modeled by $E(t)=-t^3+6t^2$ where $t$ is measured in days. In this activity, you will use the first and second derivatives to study the behavior of the model.
#
# You will:
# - define the engagement function,
# - define its first and second derivatives,
# - find the critical points,
# - find the inflection point,
# - and graph the function while marking those important points.
#
# This helps us answer questions such as:
# - When does engagement stop increasing?
# - When does growth begin to slow down?
# - When does the model change concavity?

# %% [markdown]
# **Question 1:** Create a user-defined function that models engagement. Call the function `E`.

# %%
def E(t):
    ...

# %%
E(3)

# %%
grader.check("q1")

# %% [markdown]
# **QUESTION 2:** Create 2 user-defined function that represent the first and second derivative for $E(t)$. Call the functions `dE` and `ddE` to represents the first and second derivative, respectively.

# %%
def dE(t):
    ...
def ddE(t):
    ...

# %%
ddE(3)

# %%
grader.check("q2")

# %% [markdown]
# **Question 3:** Using the data points in `t`, create a line plot, stored in `ax`, between the time points $t$ and their evaluated first derivative $\frac{dE}{dt}$. Additionally, plot a horizontal line at $y=0$.

# %%
fig, ax = plt.subplots()
...
plt.show()

# %%
grader.check("q3")

# %% [markdown]
# **Question 4:** Using the data points in `t`, create a line plot, stored in `bx`, between the time points $t$ and their evaluated second derivative $\frac{d^2E}{dt^2}$. Additionally, plot a horizontal line at $y=0$.

# %%
fig, bx = plt.subplots()
...
plt.show()

# %%
grader.check("q4")

# %% [markdown]
# **Question 5:** Store the critical values and inflection point in the objects `crit_pts` amd `infl_pt`, respectively. Use the plots from Question 3 and 4 to identify the points.

# %%
crit_pts = ...
infl_pt = ...

# %%
grader.check("q5")

# %% [markdown]
# **Question 4:** Create a plot, called `cx`, visualizing the function $E(t)$, with the critical points and inflection point in the plot.

# %%
fig, cx = plt.subplots()
...
plt.show()

# %%
grader.check("q4")

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will check if submitted code is ready to be graded. **Please save before submitting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.check_all()
