# %%
# Initialize Otter
# %pip install otter-grader==6.1.6

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # download test files
    import requests, os
    os.makedirs('tests', exist_ok=True)
    api = "https://api.github.com/repos/inqs909/d260_hw/contents/a7/tests"
    for f in requests.get(api).json():
        open(f"tests/{f['name']}", 'w').write(requests.get(f['download_url']).text)

    # Initialize Otter
    import otter
    grader = otter.Notebook()
else:
    import otter
    grader = otter.Notebook("a7.ipynb")

# %% [markdown]
# ## Assignment X: Approximating Accumulation with Rectangles

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad

# Do Not Change
a = 0
b = 4
n = 100

# %% [markdown]
# A server processes requests at a rate $R(t)=50+10t$ requests per minute, where $t$ is measured in minutes.
# You will approximate the total number of requests processed from $t=0$ to $t=4$ in two ways:
# 1. Using a left Riemann sum with rectangles
# 2. Using Scipy’s built-in integral function [`quad`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.quad.html)
#
# You will then compare the approximation to the built-in result.

# %% [markdown]
# **Question 1:** Create a user-defined function called `R` of $R(t)$.

# %%
def R(t):
    ...

# %%
grader.check("q1")

# %% [markdown]
# **Question 2:** The objects `a` and `b` contain the end points of the interval to evaluate, and `n` contains the number of rectangles to compute the left Riemann sum. Compute the width of each rectangle in the interval, store the value in `dx.

# %%
dx = ...

# %%
grader.check("q2")

# %% [markdown]
# **Question 3:** Obtain the left end points used for the Riemann sum and store it in an object called `t_left`. Hint: use `np.arrange`.

# %%
t_left = ...

# %%
grader.check("q3")

# %% [markdown]
# **Question 4:** Approximate the integral using the left Riemann sum approximation. Store the result in an object called `approx_total`. Hint: use `np.sum`.

# %%
approx_total = ...

# %%
grader.check("q4")

# %% [markdown]
# **Question 5:** Use Scipy's `quad` function to approximate the integral. Only store the first element from `quad` in `exact_total`.

# %%
exact_total = ...

# %%
grader.check("q5")

# %% [markdown]
# **Question 6:** Compute the absolute error between the two methods and store the method in an object called `error_total`

# %%
error_total = ...

print(f"Approximate total: {approx_total:.2f}")
print(f"Exact total: {exact_total:.2f}")
print(f"Error: {error_total:.2f}")

# %%
grader.check("q6")

# %% [markdown]
# **Question 7:** Create a plot, called `ax`, visualizing the $R(t)$.

# %%
t_plot = np.linspace(a, b, 200)

fig, ax = plt.subplots()
...
plt.show()

# %%
grader.check("q7")

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will check if submitted code is ready to be graded. **Please save before submitting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.check_all()
