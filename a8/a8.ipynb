# %%
# Initialize Otter
# %pip install otter-grader==6.1.6

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # download test files
    import requests, os
    os.makedirs('tests', exist_ok=True)
    api = "https://api.github.com/repos/inqs909/d260_hw/contents/a8/tests"
    for f in requests.get(api).json():
        open(f"tests/{f['name']}", 'w').write(requests.get(f['download_url']).text)

    # Initialize Otter
    import otter
    grader = otter.Notebook()
else:
    import otter
    grader = otter.Notebook("a8.ipynb")

# %% [markdown]
# ## Assignment X: Simulating Logistic Growth

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from scipy.integrate._ivp.ivp import OdeResult


P0 = 50
M = 500
k = 0.4

tspan = (0, 20)

# %% [markdown]
# A psychology research team is studying adoption of a wellness app that helps students practice stress-management habits. Let $P(t)$ represent the number of students regularly using the app after $t$ weeks.
# The model is logistic:
#
# $$
# \frac{dP}{dt}=kP\left(1-\frac{P}{M}\right)
# $$
#
# where $M$ is the saturation level, $k$ is the growth rate, and $P_0$ is the initial number of users. Using the initia values: $P_0=50$, $M=500$, $k=0.4$, use the `solve_ivp` function from scipy module to simulate the model, then compare your numerical solution with the exact logistic solution:
#
# $$
# P(t) = \frac{M}{1+\left(\frac{M-P_0}{P_0}\right)e^{-kt}}
# $$

# %% [markdown]
# **Question 1:** Create a user-defined function called `dPdt` that follows $dP/dt$ as stated above.

# %%
def dPdt(t, P):
    ...

# %%
grader.check("q1")

# %% [markdown]
# **Question 2:** Use the [`solve_ivp`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.solve_ivp.html) function from `scipy` to solve the ordinary differential equation `dPdt`. Use the values `tspan` (the time values to focus on), `P0` (and the initial Population size; note put the object in squared brackets), and `dense_output=True` (to construct continuous values). Store the solution in an object called `sol`.

# %%
sol = ...

# %%
grader.check("q2")

# %% [markdown]
# **Question 3:** Obtain the time values used to construct the ODE solver and store it into an object called `t_num`. Obtain the solutions of the solver and put it into an object called `P_num` (Note: you need to extract the first element of the solved values, `y[0]`).

# %%
t_num = ...
P_num = ...

# %%
grader.check("q3")

# %% [markdown]
# **Question 4:** Obtain the theoretical values of the solved differential equation, with the equation above. Store the values in an object called `P_exact`. Use the time values from `t_num`.

# %%
P_exact = ...

# %%
grader.check("q4")

# %% [markdown]
# **Question 5:** Obtain and print the maximum absolute error between the ODE solver and exact solution from all the time points in `t_num`. Store the max absolute error in `max_error`

# %%
max_error = ...
print("Maximum error:", max_error)

# %%
grader.check("q5")

# %% [markdown]
# **Question 6:** Create a plot, called `ax`, visualizing the data points, `t_num` and `P_num` as a scatter plot. Afterwards impose a line using the exact values from `P_exact`.

# %%
fig, ax = plt.subplots()
...
plt.show()

# %%
grader.check("q6")

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will check if submitted code is ready to be graded. **Please save before submitting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.check_all()
